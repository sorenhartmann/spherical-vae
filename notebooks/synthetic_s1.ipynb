# %%
# %load_ext autoreload
# %autoreload 2

from src.data.synthetic import SyntheticS1
import seaborn as sns
from sklearn.manifold import MDS

data = SyntheticS1()
X_latent = data.X_latent 
X = data.X 
y = data.y 
X_mds = MDS().fit_transform(X)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sns.scatterplot(x=X_latent[:,0], y=X_latent[:, 1], hue=y)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=X_mds[:,0], y=X_mds[:, 1], hue=y)
# Out:
# <AxesSubplot:>
